# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\internship\\datascience\\dsclass\\MissingMigrantsGlobal.csv",encoding="latin",sep="\t")

# %%
data.head()
# Out:
#    Web ID Region of Incident   Reported Date  Reported Year Reported Month  \
# 0   51591      Mediterranean  March 28, 2019           2019            Mar
# 1   51588      Mediterranean  March 26, 2019           2019            Mar
# 2   51589      Mediterranean  March 26, 2019           2019            Mar
# 3   51590      Mediterranean  March 26, 2019           2019            Mar
# 4   51587    Central America  March 25, 2019           2019            Mar
#
#    Number Dead  Minimum Estimated Number of Missing  Total Dead and Missing  \
# 0          NaN                                  2.0                       2
# 1          4.0                                  NaN                       4
# 2          1.0                                  NaN                       1
# 3          1.0                                  NaN                       1
# 4          1.0                                  NaN                       1
#
# ...

# %%
#1. 

data["Region of Incident"].value_counts()[:10]
# Out:
# US-Mexico Border      1337
# North Africa          1239
# Mediterranean          984
# Sub-Saharan Africa     475
# Central America        309
# Europe                 249
# Horn of Africa         235
# Middle East            164
# South Asia             151
# Southeast Asia          96
# Name: Region of Incident, dtype: int64

# %%
data.groupby("Region of Incident").count().sort_values(by="Web ID",ascending=False)[:10][["Number of Females","Number of Males","Number of Children"]]
# Out:
#                     Number of Females  Number of Males  Number of Children
# Region of Incident
# US-Mexico Border                   89              942                  20
# North Africa                      200              338                 107
# Mediterranean                     256              374                 235
# Sub-Saharan Africa                150              296                 107
# Central America                    26              252                  25
# Europe                             27              196                  30
# Horn of Africa                     25               77                  13
# Middle East                        37              103                  43
# South Asia                         15              130                  15
# Southeast Asia                     39               52                  37

# %%
data.groupby("Region of Incident").count().sort_values(by="Web ID",ascending=False)[:10]
# Out:
#                     Web ID  Reported Date  Reported Year  Reported Month  \
# Region of Incident
# US-Mexico Border      1337           1337           1337            1337
# North Africa          1239           1239           1239            1239
# Mediterranean          984            984            984             984
# Sub-Saharan Africa     475            475            475             475
# Central America        309            309            309             309
# Europe                 249            249            249             249
# Horn of Africa         235            235            235             235
# Middle East            164            164            164             164
# South Asia             151            151            151             151
# Southeast Asia          96             96             96              96
#
#                     Number Dead  Minimum Estimated Number of Missing  \
# Region of Incident
# ...

# %%
#total = sum of number of males+ number of females + number of children
#male_per = number of males/total

# %%
data["Information Source"]
# Out:
# 0               Hellenic Coast Guard via IOM Greece
# 1                Turkish Coast Guard via IOM Turkey
# 2                  Ceuta al día, El Pueblo de Ceuta
# 3                                El Pueblo de Ceuta
# 4                   Megalópolis, Línea de contraste
#                            ...
# 5328             Ministry of Foreign Affairs Mexico
# 5329              EUBusiness (Agence France-Presse)
# 5330     Pima County Office of the Medical Examiner
# 5331     Pima County Office of the Medical Examiner
# 5332    Humane Borders Arizona Open GIS Initiative
# Name: Information Source, Length: 5333, dtype: object

# %%
data.groupby("Region of Incident")

# %%
data["Region of Incident"].value_counts()
# Out:
# US-Mexico Border      1337
# North Africa          1239
# Mediterranean          984
# Sub-Saharan Africa     475
# Central America        309
# Europe                 249
# Horn of Africa         235
# Middle East            164
# South Asia             151
# Southeast Asia          96
# Caribbean               59
# South America           28
# East Asia                5
# North America            1
# Central Asia             1
# Name: Region of Incident, dtype: int64

# %%
data.groupby("Region of Incident")["Information Source"].count()
# Out:
# Region of Incident
# Caribbean               59
# Central America        309
# Central Asia             1
# East Asia                5
# Europe                 249
# Horn of Africa         235
# Mediterranean          984
# Middle East            164
# North Africa          1239
# North America            1
# South America           28
# South Asia             151
# Southeast Asia          95
# Sub-Saharan Africa     475
# US-Mexico Border      1336
# Name: Information Source, dtype: int64

# %%
data["Information Source"].value_counts()
# Out:
# Mixed Migration Monitoring Mechanism Initiative (4Mi)       960
# Mixed Migration Monitoring Mechanism Initiative (4mi)       706
# Pima County Office of the Medical Examiner                  681
# MHub                                                        190
# IOM Libya                                                   111
#                                                            ...
# Miami Herald                                                  1
# Turkish Coast Guard, IOM Turkey, Kibrik Postasi, Reuters      1
# Migrant Shelter La 72                                         1
# Diario Del Sur                                                1
# Stereo Romance                                                1
# Name: Information Source, Length: 1356, dtype: int64

# %%
data["Region of Incident"].value_counts()
# Out:
# US-Mexico Border      1337
# North Africa          1239
# Mediterranean          984
# Sub-Saharan Africa     475
# Central America        309
# Europe                 249
# Horn of Africa         235
# Middle East            164
# South Asia             151
# Southeast Asia          96
# Caribbean               59
# South America           28
# East Asia                5
# North America            1
# Central Asia             1
# Name: Region of Incident, dtype: int64

# %%
data["Region of Incident"].value_counts().values
# Out:
# array([1337, 1239,  984,  475,  309,  249,  235,  164,  151,   96,   59,
#          28,    5,    1,    1], dtype=int64)

# %%
data["Region of Incident"].value_counts().index
# Out:
# Index(['US-Mexico Border', 'North Africa', 'Mediterranean',
#        'Sub-Saharan Africa', 'Central America', 'Europe', 'Horn of Africa',
#        'Middle East', 'South Asia', 'Southeast Asia', 'Caribbean',
#        'South America', 'East Asia', 'North America', 'Central Asia'],
#       dtype='object')

# %%
data[data["Region of Incident"]=="North Africa"]["Information Source"].value_counts()[:10]
# Out:
# Mixed Migration Monitoring Mechanism Initiative (4Mi)                   674
# Mixed Migration Monitoring Mechanism Initiative (4mi)                   316
# MHub                                                                    186
# IOM Libya                                                                 9
# IOM Niger                                                                 4
# Asociación Pro Derechos Humanos de Andalucía                              3
# Alarm Phone Sahara                                                        2
# Asociacion Pro Derechos Humanos de Andalucia                              2
# IOM DTM Libya                                                             1
# Association Marocaine des Droits Humains - Section Nador, Nador City      1
# Name: Information Source, dtype: int64

# %%
#3
for i in data["Region of Incident"].value_counts().index:
    #print(data[data["Region of Incident"]==i]["Information Source"].value_counts()[:10])
    data[data["Region of Incident"]==i]["Information Source"].value_counts()[:10].plot(kind='bar')
    plt.show()

# %%
#4

# %%
data["Cause of Death"]
# Out:
# 0                Presumed drowning
# 1                Presumed drowning
# 2                Presumed drowning
# 3                Presumed drowning
# 4                  Fall from train
#                    ...
# 5328                          Shot
# 5329                  Hyperthermia
# 5330    Unknown (skeletal remains)
# 5331    Unknown (skeletal remains)
# 5332    Unknown (skeletal remains)
# Name: Cause of Death, Length: 5333, dtype: object

# %%
data.groupby("Region of Incident").apply(lambda x : x)
# Out:
#       Web ID Region of Incident     Reported Date  Reported Year  \
# 0      51591      Mediterranean    March 28, 2019           2019
# 1      51588      Mediterranean    March 26, 2019           2019
# 2      51589      Mediterranean    March 26, 2019           2019
# 3      51590      Mediterranean    March 26, 2019           2019
# 4      51587    Central America    March 25, 2019           2019
# ...      ...                ...               ...            ...
# 5328   39207   US-Mexico Border  January 16, 2014           2014
# 5329   39368             Europe  January 16, 2014           2014
# 5330   39257   US-Mexico Border  January 14, 2014           2014
# 5331   39256   US-Mexico Border  January 12, 2014           2014
# 5332   39206   US-Mexico Border  January 06, 2014           2014
#
#      Reported Month  Number Dead  Minimum Estimated Number of Missing  \
# 0               Mar          NaN                                  2.0
# ...

# %%
data.shape
# Out:
# (5333, 20)

# %%
#4
for i in data["Region of Incident"].value_counts().index:
    #print(data[data["Region of Incident"]==i]["Information Source"].value_counts()[:10])
    data[data["Region of Incident"]==i]["Cause of Death"].value_counts()[:10].plot(kind='bar')
    plt.title(i,fontdict={"color":"red","fontsize":20})
    plt.show()

# %%
data.columns
# Out:
# Index(['Web ID', 'Region of Incident', 'Reported Date', 'Reported Year',
#        'Reported Month', 'Number Dead', 'Minimum Estimated Number of Missing',
#        'Total Dead and Missing', 'Number of Survivors', 'Number of Females',
#        'Number of Males', 'Number of Children', 'Cause of Death',
#        'Location Description', 'Information Source', 'Location Coordinates',
#        'Migration Route', 'URL', 'UNSD Geographical Grouping',
#        'Source Quality'],
#       dtype='object')

# %%
data["Reported Year"]
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
#         ...
# 5328    2014
# 5329    2014
# 5330    2014
# 5331    2014
# 5332    2014
# Name: Reported Year, Length: 5333, dtype: int64

# %%
data[data["Reported Year"]==2019]
# Out:
#      Web ID Region of Incident     Reported Date  Reported Year  \
# 0     51591      Mediterranean    March 28, 2019           2019
# 1     51588      Mediterranean    March 26, 2019           2019
# 2     51589      Mediterranean    March 26, 2019           2019
# 3     51590      Mediterranean    March 26, 2019           2019
# 4     51587    Central America    March 25, 2019           2019
# ..      ...                ...               ...            ...
# 138   48075      Mediterranean  January 04, 2019           2019
# 139   48117      South America  January 04, 2019           2019
# 140   48071      Mediterranean  January 02, 2019           2019
# 141   48072      Mediterranean  January 02, 2019           2019
# 142   48073      Mediterranean  January 02, 2019           2019
#
#     Reported Month  Number Dead  Minimum Estimated Number of Missing  \
# 0              Mar          NaN                                  2.0
# ...

# %%
data.groupby('Reported Month')['Reported Year'] == 2019
# Out:
# False

# %%
data[data["Reported Year"]==2019].count()
# Out:
# Web ID                                 143
# Region of Incident                     143
# Reported Date                          143
# Reported Year                          143
# Reported Month                         143
# Number Dead                            132
# Minimum Estimated Number of Missing     20
# Total Dead and Missing                 143
# Number of Survivors                     35
# Number of Females                       21
# Number of Males                         75
# Number of Children                      16
# Cause of Death                         143
# Location Description                   143
# Information Source                     143
# Location Coordinates                   143
# Migration Route                         53
# URL                                    133
# UNSD Geographical Grouping             143
# Source Quality                         143
# dtype: int64

# %%
#5
data[data['Reported Year']==2019].groupby('Reported Month').count()["Web ID"]
# Out:
# Reported Month
# Feb    51
# Jan    57
# Mar    35
# Name: Web ID, dtype: int64

# %%
data[data['Reported Year']==2019]["Reported Month"].value_counts()
# Out:
# Jan    57
# Feb    51
# Mar    35
# Name: Reported Month, dtype: int64

# %%
#6
data["Migration Route"].value_counts()
# Out:
# Central America to US                        1507
# Central Mediterranean                         499
# Western Mediterranean                         255
# Eastern Mediterranean                         230
# Western Balkans                                64
# Calais to United Kingdom                       51
# Western African                                15
# Horn Africa to Yemen                           15
# Italy to France                                 9
# Darien Gap                                      7
# Caribbean to Central America                    3
# Dominican Republic to Puerto Rico               2
# Malaysia to Indonesia                           1
# Venezuela to Curaçao                            1
# From Haiti to Dajabon, Dominican Republic       1
# Name: Migration Route, dtype: int64

# %%
#7
data.groupby("Reported Year").count()
# Out:
#                Web ID  Region of Incident  Reported Date  Reported Month  \
# Reported Year
# 2014              245                 245            245             245
# 2015              808                 808            808             808
# 2016             1275                1275           1275            1275
# 2017             1356                1356           1356            1356
# 2018             1506                1506           1506            1506
# 2019              143                 143            143             143
#
#                Number Dead  Minimum Estimated Number of Missing  \
# Reported Year
# 2014                   221                                   96
# 2015                   783                                   89
# 2016                  1232                                  101
# 2017                  1308                                   95
# 2018                  1466                                  102
# ...

# %%
data["Reported Year"].value_counts().plot(kind="bar")
