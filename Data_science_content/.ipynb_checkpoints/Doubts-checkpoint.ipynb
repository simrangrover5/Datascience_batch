# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("top50.csv",encoding="latin",index_col=0)

# %%
data.head()
# Out:
#                         Track.Name    Artist.Name           Genre  \
# 1                         Señorita   Shawn Mendes    canadian pop
# 2                            China       Anuel AA  reggaeton flow
# 3    boyfriend (with Social House)  Ariana Grande       dance pop
# 4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 1               117      55            76              -6         8        75
# 2               105      81            79              -4         8        61
# 3               190      80            40              -4        16        70
# 4                93      65            64              -8         8        55
# 5               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# ...

# %%
data = pd.read_csv("top50.csv",encoding="latin")

# %%
data.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data.shape
# Out:
# (50, 13)

# %%
df = pd.read_csv("Apple_Stock/appl_1980_2014.csv")

# %%
df.head()
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
# Date         8465 non-null object
# Open         8465 non-null float64
# High         8465 non-null float64
# Low          8465 non-null float64
# Close        8465 non-null float64
# Volume       8465 non-null int64
# Adj Close    8465 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 463.1+ KB

# %%
df['Date']
# Out:
# 0       2014-07-08
# 1       2014-07-07
# 2       2014-07-03
# 3       2014-07-02
# 4       2014-07-01
#            ...
# 8460    1980-12-18
# 8461    1980-12-17
# 8462    1980-12-16
# 8463    1980-12-15
# 8464    1980-12-12
# Name: Date, Length: 8465, dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.index = df['Date']

# %%
df.head()
# Out:
#                  Date   Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 2014-07-07 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-03 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-02 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-01 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...           ...    ...    ...    ...        ...        ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 6 columns]

# %%
df.resample('M')

# %%
help(df.resample)
# Out:
# Help on method resample in module pandas.core.generic:
#
# resample(rule, how=None, axis=0, fill_method=None, closed=None, label=None, convention='start', kind=None, loffset=None, limit=None, base=0, on=None, level=None) method of pandas.core.frame.DataFrame instance
#     Resample time-series data.
#
#     Convenience method for frequency conversion and resampling of time
#     series. Object must have a datetime-like index (`DatetimeIndex`,
#     `PeriodIndex`, or `TimedeltaIndex`), or pass datetime-like values
#     to the `on` or `level` keyword.
#
#     Parameters
#     ----------
#     rule : DateOffset, Timedelta or str
#         The offset string or object representing target conversion.
#     how : str
#         Method for down/re-sampling, default to 'mean' for downsampling.
#
#         .. deprecated:: 0.18.0
#            The new syntax is ``.resample(...).mean()``, or
#            ``.resample(...).apply(<func>)``
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
df.resample("3M").sum()
# Out:
#                 Open      High       Low     Close      Volume  Adj Close
# Date
# 1980-12-31    396.26    397.38    395.76    395.76   336212800       6.15
# 1981-03-31   1718.60   1723.60   1712.90   1712.90   407831200      26.71
# 1981-06-30   1831.70   1837.77   1827.15   1827.15   519478400      28.45
# 1981-09-30   1366.98   1371.18   1361.37   1361.37   489932800      21.20
# 1981-12-31   1228.08   1234.36   1224.99   1224.99   631993600      19.06
# ...              ...       ...       ...       ...         ...        ...
# 2013-09-30  29726.42  30002.15  29452.81  29711.71  5806848600    4160.71
# 2013-12-31  33833.39  34108.78  33578.46  33854.27  5030071200    4770.05
# 2014-03-31  32494.28  32749.97  32246.27  32488.88  4912005000    4604.67
# 2014-06-30  28638.62  28870.93  28461.95  28705.49  4249238600    5351.04
# 2014-09-30    471.47    475.02    467.44    472.35   210918300     472.35
#
# [136 rows x 6 columns]

# %%
df.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %%
df.resample("M").apply(lambda x : x)
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 2014-06-30  222.360000  224.084286  220.735714  222.658095  5.745506e+07
# 2014-07-31   94.294000   95.004000   93.488000   94.470000  4.218366e+07
#
#             Adj Close
# Date
# 1980-12-31   0.473077
# 1981-01-30   0.493810
# ...

# %%
df.index.max()
# Out:
# Timestamp('2014-07-08 00:00:00')

# %%
df.index.min()
# Out:
# Timestamp('1980-12-12 00:00:00')

# %%
df.sort_index()
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# ...           ...    ...    ...    ...        ...        ...
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
#
# [8465 rows x 6 columns]

# %%
df.index.max() - df.index.min()  #10
# Out:
# Timedelta('12261 days 00:00:00')

# %%
df.index
# Out:
# DatetimeIndex(['2014-07-08', '2014-07-07', '2014-07-03', '2014-07-02',
#                '2014-07-01', '2014-06-30', '2014-06-27', '2014-06-26',
#                '2014-06-25', '2014-06-24',
#                ...
#                '1980-12-26', '1980-12-24', '1980-12-23', '1980-12-22',
#                '1980-12-19', '1980-12-18', '1980-12-17', '1980-12-16',
#                '1980-12-15', '1980-12-12'],
#               dtype='datetime64[ns]', name='Date', length=8465, freq=None)

# %%
month = []
for i in df.index:
    #print(str(i).split()[0].split("-"))
    m = str(i).split()[0].split("-")[:2]
    if m not in month:
        month.append(m)
print(len(month))
# Out:
# 404

# %%
df.resample("M").mean()
# Out:
#                   Open        High         Low       Close        Volume  \
# Date
# 1980-12-31   30.481538   30.567692   30.443077   30.443077  2.586252e+07
# 1981-01-31   31.754762   31.826667   31.654762   31.654762  7.249867e+06
# 1981-02-28   26.480000   26.572105   26.407895   26.407895  4.231832e+06
# 1981-03-31   24.937727   25.016818   24.836364   24.836364  7.962691e+06
# 1981-04-30   27.286667   27.368095   27.227143   27.227143  6.392000e+06
# ...                ...         ...         ...         ...           ...
# 2014-03-31  533.593333  536.453810  530.070952  533.214286  5.954403e+07
# 2014-04-30  540.081905  544.349048  536.262381  541.074286  7.660787e+07
# 2014-05-31  601.301905  606.372857  598.332857  603.195714  6.828177e+07
# 2014-06-30  222.360000  224.084286  220.735714  222.658095  5.745506e+07
# 2014-07-31   94.294000   95.004000   93.488000   94.470000  4.218366e+07
#
#             Adj Close
# Date
# 1980-12-31   0.473077
# 1981-01-31   0.493810
# ...

# %%
df.loc['1981-02-28']
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Adj Close]
# Index: []

# %%
len(df.resample("BM").mean())
# Out:
# 404

# %%
len(df.resample("M").mean())
# Out:
# 404

# %%
#merge ,agg, api, scraping, pivot table
