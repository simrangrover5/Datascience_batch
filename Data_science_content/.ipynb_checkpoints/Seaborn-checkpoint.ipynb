# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
tip = sns.load_dataset("tips")

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.style.set_table_styles([{'selector':'tr:hover','props':[('background-color','#aaabbb')]}])
# Out:
# <style  type="text/css" >
#     #T_87c7dcf0_aa3c_11ea_8695_b4b686ed43e4 tr:hover {
#           background-color: #aaabbb;
#     }</style><table id="T_87c7dcf0_aa3c_11ea_8695_b4b686ed43e4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_87c7dcf0_aa3c_11ea_8695_b4b686ed43e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_87c7dcf0_aa3c_11ea_8695_b4b686ed43e4row0_col0" class="data row0 col0" >16.99</td>
# ...

# %%
tip.style.set_table_styles([{'selector':'td:hover','props':[('background-color','coral')]}])
# Out:
# <style  type="text/css" >
#     #T_9a313bcc_aa3c_11ea_b9aa_b4b686ed43e4 td:hover {
#           background-color: coral;
#     }</style><table id="T_9a313bcc_aa3c_11ea_b9aa_b4b686ed43e4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a313bcc_aa3c_11ea_b9aa_b4b686ed43e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9a313bcc_aa3c_11ea_b9aa_b4b686ed43e4row0_col0" class="data row0 col0" >16.99</td>
# ...

# %%
tip.style.set_table_styles([{'selector':'tr:nth-of-type(even)','props':[('background','coral')]}])
# Out:
# <style  type="text/css" >
#     #T_e2b5c150_aa3c_11ea_b1a8_b4b686ed43e4 tr:nth-of-type(even) {
#           background: coral;
#     }</style><table id="T_e2b5c150_aa3c_11ea_b1a8_b4b686ed43e4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e2b5c150_aa3c_11ea_b1a8_b4b686ed43e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e2b5c150_aa3c_11ea_b1a8_b4b686ed43e4row0_col0" class="data row0 col0" >16.99</td>
# ...

# %%
tip.style.set_table_styles([{'selector':'tr:nth-of-type(even)','props':[('background','coral')]},{'selector':'tr:nth-of-type(odd)','props':[('background','#abcdef')]}])
# Out:
# <style  type="text/css" >
#     #T_04aa4118_aa3d_11ea_a32b_b4b686ed43e4 tr:nth-of-type(even) {
#           background: coral;
#     }    #T_04aa4118_aa3d_11ea_a32b_b4b686ed43e4 tr:nth-of-type(odd) {
#           background: #abcdef;
#     }</style><table id="T_04aa4118_aa3d_11ea_a32b_b4b686ed43e4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_04aa4118_aa3d_11ea_a32b_b4b686ed43e4level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
tip[['tip']].style.applymap(lambda x :'color : red' if x<=2 else 'color:white' )
# Out:
# <style  type="text/css" >
#     #T_60d9529a_aa3d_11ea_b976_b4b686ed43e4row0_col0 {
#             color :  red;
#         }    #T_60d9529a_aa3d_11ea_b976_b4b686ed43e4row1_col0 {
#             color :  red;
#         }    #T_60d9529a_aa3d_11ea_b976_b4b686ed43e4row2_col0 {
#             color: white;
#         }    #T_60d9529a_aa3d_11ea_b976_b4b686ed43e4row3_col0 {
#             color: white;
#         }    #T_60d9529a_aa3d_11ea_b976_b4b686ed43e4row4_col0 {
#             color: white;
#         }    #T_60d9529a_aa3d_11ea_b976_b4b686ed43e4row5_col0 {
#             color: white;
#         }    #T_60d9529a_aa3d_11ea_b976_b4b686ed43e4row6_col0 {
#             color :  red;
#         }    #T_60d9529a_aa3d_11ea_b976_b4b686ed43e4row7_col0 {
#             color: white;
#         }    #T_60d9529a_aa3d_11ea_b976_b4b686ed43e4row8_col0 {
#             color :  red;
#         }    #T_60d9529a_aa3d_11ea_b976_b4b686ed43e4row9_col0 {
#             color: white;
# ...

# %%
tip[['tip','total_bill']].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_79ee77b8_aa3d_11ea_88de_b4b686ed43e4row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_79ee77b8_aa3d_11ea_88de_b4b686ed43e4row0_col1 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_79ee77b8_aa3d_11ea_88de_b4b686ed43e4row1_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_79ee77b8_aa3d_11ea_88de_b4b686ed43e4row1_col1 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_79ee77b8_aa3d_11ea_88de_b4b686ed43e4row2_col0 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_79ee77b8_aa3d_11ea_88de_b4b686ed43e4row2_col1 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_79ee77b8_aa3d_11ea_88de_b4b686ed43e4row3_col0 {
#             background-color:  #ced0e6;
#             color:  #000000;
# ...

# %%
tip[['tip','total_bill']].style.background_gradient(cmap="Greens")
# Out:
# <style  type="text/css" >
#     #T_8e36c31c_aa3d_11ea_ad34_b4b686ed43e4row0_col0 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_8e36c31c_aa3d_11ea_ad34_b4b686ed43e4row0_col1 {
#             background-color:  #bbe4b4;
#             color:  #000000;
#         }    #T_8e36c31c_aa3d_11ea_ad34_b4b686ed43e4row1_col0 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_8e36c31c_aa3d_11ea_ad34_b4b686ed43e4row1_col1 {
#             background-color:  #dff3da;
#             color:  #000000;
#         }    #T_8e36c31c_aa3d_11ea_ad34_b4b686ed43e4row2_col0 {
#             background-color:  #bee5b8;
#             color:  #000000;
#         }    #T_8e36c31c_aa3d_11ea_ad34_b4b686ed43e4row2_col1 {
#             background-color:  #a0d99b;
#             color:  #000000;
#         }    #T_8e36c31c_aa3d_11ea_ad34_b4b686ed43e4row3_col0 {
#             background-color:  #c6e8bf;
#             color:  #000000;
# ...

# %%
tip[['tip','total_bill']].style.background_gradient(cmap="hot")
# Out:
# <style  type="text/css" >
#     #T_95e869d8_aa3d_11ea_8cea_b4b686ed43e4row0_col0 {
#             background-color:  #0b0000;
#             color:  #f1f1f1;
#         }    #T_95e869d8_aa3d_11ea_8cea_b4b686ed43e4row0_col1 {
#             background-color:  #cd0000;
#             color:  #f1f1f1;
#         }    #T_95e869d8_aa3d_11ea_8cea_b4b686ed43e4row1_col0 {
#             background-color:  #3a0000;
#             color:  #f1f1f1;
#         }    #T_95e869d8_aa3d_11ea_8cea_b4b686ed43e4row1_col1 {
#             background-color:  #6e0000;
#             color:  #f1f1f1;
#         }    #T_95e869d8_aa3d_11ea_8cea_b4b686ed43e4row2_col0 {
#             background-color:  #c50000;
#             color:  #f1f1f1;
#         }    #T_95e869d8_aa3d_11ea_8cea_b4b686ed43e4row2_col1 {
#             background-color:  #ff0800;
#             color:  #f1f1f1;
#         }    #T_95e869d8_aa3d_11ea_8cea_b4b686ed43e4row3_col0 {
#             background-color:  #b50000;
#             color:  #f1f1f1;
# ...

# %%
plt.rcParams['figure.figsize'] = 11,5
plt.rcParams['xtick.color'] = 'red'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.color'] = 'red'
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['axes.labelcolor'] = "#FFC300"
plt.rcParams['axes.labelsize'] = 20

# %%
sns.lineplot(tip['tip'],tip['total_bill'])
plt.show()

# %%
iris = sns.load_dataset('iris')

# %%
sns.lineplot(iris['sepal_length'],iris['sepal_width'],markers=True,dashes=True)
plt.show()

# %%
plt.plot(iris['sepal_length'],iris['sepal_width'],'o--')

# %%
sns.lineplot(tip['size'],tip['total_bill'],color="coral")
plt.show()

# %%
plt.plot(tip['size'],tip['total_bill'])
plt.show()

# %%
plt.scatter(iris['sepal_length'],iris['petal_length'])
plt.show()

# %%
sns.scatterplot(iris['sepal_length'],iris['petal_length'])
plt.show()

# %%
c = iris['species'].map({'setosa':0,'virginica':1,'versicolor':2})

# %%
iris['species'].value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %%
sns.scatterplot(iris['sepal_length'],iris['petal_length'],hue=c,palette='rainbow')
plt.show()

# %%
cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
sns.scatterplot(iris['sepal_length'],iris['petal_length'],hue=c,palette=cmap)
plt.show()

# %%
sns.scatterplot('total_bill','tip',data=tip,hue="sex",size="smoker")
plt.show()

# %%
sns.scatterplot('total_bill','tip',data=tip,hue="day")
plt.show()

# %%
mpg = sns.load_dataset('mpg')

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg['cylinders'].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
data = mpg[:100]

# %%
sns.scatterplot('mpg','horsepower',data=data,size='cylinders',color='red')
plt.show()

# %%
c = data['origin'].map({'usa':0,'europe':1,'japan':2})

# %%
sns.scatterplot('mpg','horsepower',data=data,size='cylinders',color='red',hue=c,palette='hot')
plt.show()

# %%
data['origin'].value_counts()
# Out:
# usa       75
# europe    14
# japan     11
# Name: origin, dtype: int64

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.countplot()
