# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.randint(10,50,50).reshape(10,5),columns=list("ABCDE"))

# %%
df.shape
# Out:
# (10, 5)

# %%
df
# Out:
#     A   B   C   D   E
# 0  23  31  12  12  44
# 1  40  33  36  20  30
# 2  45  38  33  21  21
# 3  10  14  17  29  35
# 4  10  47  23  18  20
# 5  38  11  11  11  20
# 6  10  37  29  36  45
# 7  35  17  36  16  49
# 8  43  27  36  32  11
# 9  16  37  26  14  36

# %%
df.drop('B')  #axis=0 --> row
# Out:
# ---------------------------------------------------------------------
# KeyError                            Traceback (most recent call last)
# <ipython-input-14-d43b3aa9f14d> in <module>
# ----> 1 df.drop('B')  #axis=0 --> row
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df.drop(1)
# Out:
#     A   B   C   D   E
# 0  23  31  12  12  44
# 2  45  38  33  21  21
# 3  10  14  17  29  35
# 4  10  47  23  18  20
# 5  38  11  11  11  20
# 6  10  37  29  36  45
# 7  35  17  36  16  49
# 8  43  27  36  32  11
# 9  16  37  26  14  36

# %%
df.drop([2,3])
# Out:
#     A   B   C   D   E
# 0  23  31  12  12  44
# 1  40  33  36  20  30
# 4  10  47  23  18  20
# 5  38  11  11  11  20
# 6  10  37  29  36  45
# 7  35  17  36  16  49
# 8  43  27  36  32  11
# 9  16  37  26  14  36

# %%
df.drop('B',axis=1)
# Out:
#     A   C   D   E
# 0  23  12  12  44
# 1  40  36  20  30
# 2  45  33  21  21
# 3  10  17  29  35
# 4  10  23  18  20
# 5  38  11  11  20
# 6  10  29  36  45
# 7  35  36  16  49
# 8  43  36  32  11
# 9  16  26  14  36

# %%
df.drop(['A','B'],axis=1)
# Out:
#     C   D   E
# 0  12  12  44
# 1  36  20  30
# 2  33  21  21
# 3  17  29  35
# 4  23  18  20
# 5  11  11  20
# 6  29  36  45
# 7  36  16  49
# 8  36  32  11
# 9  26  14  36

# %%
df
# Out:
#     A   B   C   D   E
# 0  23  31  12  12  44
# 1  40  33  36  20  30
# 2  45  38  33  21  21
# 3  10  14  17  29  35
# 4  10  47  23  18  20
# 5  38  11  11  11  20
# 6  10  37  29  36  45
# 7  35  17  36  16  49
# 8  43  27  36  32  11
# 9  16  37  26  14  36

# %%
df['abc'] = "Faltu"

# %%
df
# Out:
#     A   B   C   D   E    abc
# 0  23  31  12  12  44  Faltu
# 1  40  33  36  20  30  Faltu
# 2  45  38  33  21  21  Faltu
# 3  10  14  17  29  35  Faltu
# 4  10  47  23  18  20  Faltu
# 5  38  11  11  11  20  Faltu
# 6  10  37  29  36  45  Faltu
# 7  35  17  36  16  49  Faltu
# 8  43  27  36  32  11  Faltu
# 9  16  37  26  14  36  Faltu

# %%
df.drop('abc',axis=1,inplace=True)

# %%
df
# Out:
#     A   B   C   D   E
# 0  23  31  12  12  44
# 1  40  33  36  20  30
# 2  45  38  33  21  21
# 3  10  14  17  29  35
# 4  10  47  23  18  20
# 5  38  11  11  11  20
# 6  10  37  29  36  45
# 7  35  17  36  16  49
# 8  43  27  36  32  11
# 9  16  37  26  14  36

# %%
df.drop(2,inplace=True)

# %%
df
# Out:
#     A   B   C   D   E
# 0  23  31  12  12  44
# 1  40  33  36  20  30
# 3  10  14  17  29  35
# 4  10  47  23  18  20
# 5  38  11  11  11  20
# 6  10  37  29  36  45
# 7  35  17  36  16  49
# 8  43  27  36  32  11
# 9  16  37  26  14  36

# %%
df.loc[1,'E'] = np.nan

# %%
df.iloc[3:7,::2] = np.nan

# %%
df
# Out:
#       A   B     C   D     E
# 0  23.0  31  12.0  12  44.0
# 1  40.0  33  36.0  20   NaN
# 3  10.0  14  17.0  29  35.0
# 4   NaN  47   NaN  18   NaN
# 5   NaN  11   NaN  11   NaN
# 6   NaN  37   NaN  36   NaN
# 7   NaN  17   NaN  16   NaN
# 8  43.0  27  36.0  32  11.0
# 9  16.0  37  26.0  14  36.0

# %%
df = pd.DataFrame(np.random.randint(10,50,50).reshape(10,5),columns=list("ABCDE"))

# %%
df.loc[1,'E'] = np.nan
df.iloc[3:7:2,::2] = np.nan

# %%
df
# Out:
#       A   B     C   D     E
# 0  27.0  45  36.0  38  28.0
# 1  18.0  26  41.0  33   NaN
# 2  10.0  46  28.0  22  37.0
# 3   NaN  24   NaN  38   NaN
# 4  41.0  31  45.0  33  13.0
# 5   NaN  19   NaN  46   NaN
# 6  13.0  31  10.0  16  17.0
# 7  30.0  12  35.0  26  44.0
# 8  48.0  34  32.0  44  15.0
# 9  15.0  15  48.0  45  20.0

# %%
df.isna()
# Out:
#        A      B      C      D      E
# 0  False  False  False  False  False
# 1  False  False  False  False   True
# 2  False  False  False  False  False
# 3   True  False   True  False   True
# 4  False  False  False  False  False
# 5   True  False   True  False   True
# 6  False  False  False  False  False
# 7  False  False  False  False  False
# 8  False  False  False  False  False
# 9  False  False  False  False  False

# %%
df[df.isna()]
# Out:
#     A   B   C   D   E
# 0 NaN NaN NaN NaN NaN
# 1 NaN NaN NaN NaN NaN
# 2 NaN NaN NaN NaN NaN
# 3 NaN NaN NaN NaN NaN
# 4 NaN NaN NaN NaN NaN
# 5 NaN NaN NaN NaN NaN
# 6 NaN NaN NaN NaN NaN
# 7 NaN NaN NaN NaN NaN
# 8 NaN NaN NaN NaN NaN
# 9 NaN NaN NaN NaN NaN

# %%
df[df>30]
# Out:
#       A     B     C     D     E
# 0   NaN  45.0  36.0  38.0   NaN
# 1   NaN   NaN  41.0  33.0   NaN
# 2   NaN  46.0   NaN   NaN  37.0
# 3   NaN   NaN   NaN  38.0   NaN
# 4  41.0  31.0  45.0  33.0   NaN
# 5   NaN   NaN   NaN  46.0   NaN
# 6   NaN  31.0   NaN   NaN   NaN
# 7   NaN   NaN  35.0   NaN  44.0
# 8  48.0  34.0  32.0  44.0   NaN
# 9   NaN   NaN  48.0  45.0   NaN

# %%
df[df['A'].isna()]
# Out:
#     A   B   C   D   E
# 3 NaN  24 NaN  38 NaN
# 5 NaN  19 NaN  46 NaN

# %%
df[['B','C']].isna()
# Out:
#        B      C
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False   True
# 4  False  False
# 5  False   True
# 6  False  False
# 7  False  False
# 8  False  False
# 9  False  False

# %%
df
# Out:
#       A   B     C   D     E
# 0  27.0  45  36.0  38  28.0
# 1  18.0  26  41.0  33   NaN
# 2  10.0  46  28.0  22  37.0
# 3   NaN  24   NaN  38   NaN
# 4  41.0  31  45.0  33  13.0
# 5   NaN  19   NaN  46   NaN
# 6  13.0  31  10.0  16  17.0
# 7  30.0  12  35.0  26  44.0
# 8  48.0  34  32.0  44  15.0
# 9  15.0  15  48.0  45  20.0

# %%
df.dropna()
# Out:
#       A   B     C   D     E
# 0  27.0  45  36.0  38  28.0
# 2  10.0  46  28.0  22  37.0
# 4  41.0  31  45.0  33  13.0
# 6  13.0  31  10.0  16  17.0
# 7  30.0  12  35.0  26  44.0
# 8  48.0  34  32.0  44  15.0
# 9  15.0  15  48.0  45  20.0

# %%
help(df.dropna)
# Out:
# Help on method dropna in module pandas.core.frame:
#
# dropna(axis=0, how='any', thresh=None, subset=None, inplace=False) method of pandas.core.frame.DataFrame instance
#     Remove missing values.
#
#     See the :ref:`User Guide <missing_data>` for more on which values are
#     considered missing, and how to work with missing data.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Determine if rows or columns which contain missing values are
#         removed.
#
#         * 0, or 'index' : Drop rows which contain missing values.
#         * 1, or 'columns' : Drop columns which contain missing value.
#
#         .. deprecated:: 0.23.0
#
#            Pass tuple or list to drop on multiple axes.
#            Only a single axis is allowed.
#
#     how : {'any', 'all'}, default 'any'
#         Determine if row or column is removed from DataFrame, when we have
#         at least one NA or all NA.
#
# ...

# %%
any([True,False,True,"hello",10])
# Out:
# True

# %%
any([0,[2,3,4],"hello world","bye"])
# Out:
# True

# %%
all([True,True,True,0])
# Out:
# False

# %%
all([True,True,True])
# Out:
# True

# %%
df
# Out:
#       A   B     C   D     E
# 0  27.0  45  36.0  38  28.0
# 1  18.0  26  41.0  33   NaN
# 2  10.0  46  28.0  22  37.0
# 3   NaN  24   NaN  38   NaN
# 4  41.0  31  45.0  33  13.0
# 5   NaN  19   NaN  46   NaN
# 6  13.0  31  10.0  16  17.0
# 7  30.0  12  35.0  26  44.0
# 8  48.0  34  32.0  44  15.0
# 9  15.0  15  48.0  45  20.0

# %%
df.dropna(how="all")
# Out:
#       A   B     C   D     E
# 0  27.0  45  36.0  38  28.0
# 1  18.0  26  41.0  33   NaN
# 2  10.0  46  28.0  22  37.0
# 3   NaN  24   NaN  38   NaN
# 4  41.0  31  45.0  33  13.0
# 5   NaN  19   NaN  46   NaN
# 6  13.0  31  10.0  16  17.0
# 7  30.0  12  35.0  26  44.0
# 8  48.0  34  32.0  44  15.0
# 9  15.0  15  48.0  45  20.0

# %%
df.loc[3,['B','D']] = np.nan
df.loc[5,['B','D']] = np.nan

# %%
df
# Out:
#       A     B     C     D     E
# 0  27.0  45.0  36.0  38.0  28.0
# 1  18.0  26.0  41.0  33.0   NaN
# 2  10.0  46.0  28.0  22.0  37.0
# 3   NaN   NaN   NaN   NaN   NaN
# 4  41.0  31.0  45.0  33.0  13.0
# 5   NaN   NaN   NaN   NaN   NaN
# 6  13.0  31.0  10.0  16.0  17.0
# 7  30.0  12.0  35.0  26.0  44.0
# 8  48.0  34.0  32.0  44.0  15.0
# 9  15.0  15.0  48.0  45.0  20.0

# %%
df.dropna(how="all")
# Out:
#       A     B     C     D     E
# 0  27.0  45.0  36.0  38.0  28.0
# 1  18.0  26.0  41.0  33.0   NaN
# 2  10.0  46.0  28.0  22.0  37.0
# 4  41.0  31.0  45.0  33.0  13.0
# 6  13.0  31.0  10.0  16.0  17.0
# 7  30.0  12.0  35.0  26.0  44.0
# 8  48.0  34.0  32.0  44.0  15.0
# 9  15.0  15.0  48.0  45.0  20.0

# %%
df.dropna(how="all",axis=1)
# Out:
#       A     B     C     D     E
# 0  27.0  45.0  36.0  38.0  28.0
# 1  18.0  26.0  41.0  33.0   NaN
# 2  10.0  46.0  28.0  22.0  37.0
# 3   NaN   NaN   NaN   NaN   NaN
# 4  41.0  31.0  45.0  33.0  13.0
# 5   NaN   NaN   NaN   NaN   NaN
# 6  13.0  31.0  10.0  16.0  17.0
# 7  30.0  12.0  35.0  26.0  44.0
# 8  48.0  34.0  32.0  44.0  15.0
# 9  15.0  15.0  48.0  45.0  20.0

# %%
df['F'] = np.nan

# %%
df
# Out:
#       A     B     C     D     E   F
# 0  27.0  45.0  36.0  38.0  28.0 NaN
# 1  18.0  26.0  41.0  33.0   NaN NaN
# 2  10.0  46.0  28.0  22.0  37.0 NaN
# 3   NaN   NaN   NaN   NaN   NaN NaN
# 4  41.0  31.0  45.0  33.0  13.0 NaN
# 5   NaN   NaN   NaN   NaN   NaN NaN
# 6  13.0  31.0  10.0  16.0  17.0 NaN
# 7  30.0  12.0  35.0  26.0  44.0 NaN
# 8  48.0  34.0  32.0  44.0  15.0 NaN
# 9  15.0  15.0  48.0  45.0  20.0 NaN

# %%
df.dropna(how="all",axis=1)
# Out:
#       A     B     C     D     E
# 0  27.0  45.0  36.0  38.0  28.0
# 1  18.0  26.0  41.0  33.0   NaN
# 2  10.0  46.0  28.0  22.0  37.0
# 3   NaN   NaN   NaN   NaN   NaN
# 4  41.0  31.0  45.0  33.0  13.0
# 5   NaN   NaN   NaN   NaN   NaN
# 6  13.0  31.0  10.0  16.0  17.0
# 7  30.0  12.0  35.0  26.0  44.0
# 8  48.0  34.0  32.0  44.0  15.0
# 9  15.0  15.0  48.0  45.0  20.0

# %%
df
# Out:
#       A     B     C     D     E   F
# 0  27.0  45.0  36.0  38.0  28.0 NaN
# 1  18.0  26.0  41.0  33.0   NaN NaN
# 2  10.0  46.0  28.0  22.0  37.0 NaN
# 3   NaN   NaN   NaN   NaN   NaN NaN
# 4  41.0  31.0  45.0  33.0  13.0 NaN
# 5   NaN   NaN   NaN   NaN   NaN NaN
# 6  13.0  31.0  10.0  16.0  17.0 NaN
# 7  30.0  12.0  35.0  26.0  44.0 NaN
# 8  48.0  34.0  32.0  44.0  15.0 NaN
# 9  15.0  15.0  48.0  45.0  20.0 NaN

# %%
df.dropna(how="all",inplace=True)

# %%
df
# Out:
#       A     B     C     D     E   F
# 0  27.0  45.0  36.0  38.0  28.0 NaN
# 1  18.0  26.0  41.0  33.0   NaN NaN
# 2  10.0  46.0  28.0  22.0  37.0 NaN
# 4  41.0  31.0  45.0  33.0  13.0 NaN
# 6  13.0  31.0  10.0  16.0  17.0 NaN
# 7  30.0  12.0  35.0  26.0  44.0 NaN
# 8  48.0  34.0  32.0  44.0  15.0 NaN
# 9  15.0  15.0  48.0  45.0  20.0 NaN

# %%
df.idxmin()
# Out:
# A    2.0
# B    7.0
# C    6.0
# D    6.0
# E    4.0
# F    NaN
# dtype: float64

# %%
df.idxmin(axis=1)
# Out:
# 0    A
# 1    A
# 2    A
# 4    E
# 6    C
# 7    B
# 8    E
# 9    A
# dtype: object

# %%
df.idxmax()
# Out:
# A    8.0
# B    2.0
# C    9.0
# D    9.0
# E    7.0
# F    NaN
# dtype: float64

# %%
t = ((1,"name","python"),(2,"nehal","dsml"),(3,"padmani","dsml"))

# %%
id1 = []
name = []
course = []
for i in t:
    id1.append(i[0])
    name.append(i[1])
    course.append(i[2])

# %%
id1
# Out:
# [1, 2, 3]

# %%
name
# Out:
# ['name', 'nehal', 'padmani']

# %%
course
# Out:
# ['python', 'dsml', 'dsml']

# %%
table = pd.DataFrame({'id':id1,'name':name,'course':course})

# %%
table
# Out:
#    id     name  course
# 0   1     name  python
# 1   2    nehal    dsml
# 2   3  padmani    dsml

# %%
def remove_null(df):
    df.dropna(how="all",axis=0,inplace=True)
    df.dropna(how="all",axis=1,inplace=True)

# %%
remove_null(df)

# %%
df
# Out:
#       A     B     C     D     E
# 0  27.0  45.0  36.0  38.0  28.0
# 1  18.0  26.0  41.0  33.0   NaN
# 2  10.0  46.0  28.0  22.0  37.0
# 4  41.0  31.0  45.0  33.0  13.0
# 6  13.0  31.0  10.0  16.0  17.0
# 7  30.0  12.0  35.0  26.0  44.0
# 8  48.0  34.0  32.0  44.0  15.0
# 9  15.0  15.0  48.0  45.0  20.0

# %%
df.loc[4,'A'] = np.nan
df.loc[7,'C'] = np.nan
df.loc[8,'D'] = np.nan

# %%
df
# Out:
#       A     B     C     D     E
# 0  27.0  45.0  36.0  38.0  28.0
# 1  18.0  26.0  41.0  33.0   NaN
# 2  10.0  46.0  28.0  22.0  37.0
# 4   NaN  31.0  45.0  33.0  13.0
# 6  13.0  31.0  10.0  16.0  17.0
# 7  30.0  12.0   NaN  26.0  44.0
# 8  48.0  34.0  32.0   NaN  15.0
# 9  15.0  15.0  48.0  45.0  20.0

# %%
df.dropna()
# Out:
#       A     B     C     D     E
# 0  27.0  45.0  36.0  38.0  28.0
# 2  10.0  46.0  28.0  22.0  37.0
# 6  13.0  31.0  10.0  16.0  17.0
# 9  15.0  15.0  48.0  45.0  20.0

# %%
df.dropna(axis=1)
# Out:
#       B
# 0  45.0
# 1  26.0
# 2  46.0
# 4  31.0
# 6  31.0
# 7  12.0
# 8  34.0
# 9  15.0

# %%
df.fillna(-234)
# Out:
#        A     B      C      D      E
# 0   27.0  45.0   36.0   38.0   28.0
# 1   18.0  26.0   41.0   33.0 -234.0
# 2   10.0  46.0   28.0   22.0   37.0
# 4 -234.0  31.0   45.0   33.0   13.0
# 6   13.0  31.0   10.0   16.0   17.0
# 7   30.0  12.0 -234.0   26.0   44.0
# 8   48.0  34.0   32.0 -234.0   15.0
# 9   15.0  15.0   48.0   45.0   20.0

# %%
df.fillna(-234,inplace=True)

# %%
df
# Out:
#        A     B      C      D      E
# 0   27.0  45.0   36.0   38.0   28.0
# 1   18.0  26.0   41.0   33.0 -234.0
# 2   10.0  46.0   28.0   22.0   37.0
# 4 -234.0  31.0   45.0   33.0   13.0
# 6   13.0  31.0   10.0   16.0   17.0
# 7   30.0  12.0 -234.0   26.0   44.0
# 8   48.0  34.0   32.0 -234.0   15.0
# 9   15.0  15.0   48.0   45.0   20.0

# %%
df[df==-234]
# Out:
#        A   B      C      D      E
# 0    NaN NaN    NaN    NaN    NaN
# 1    NaN NaN    NaN    NaN -234.0
# 2    NaN NaN    NaN    NaN    NaN
# 4 -234.0 NaN    NaN    NaN    NaN
# 6    NaN NaN    NaN    NaN    NaN
# 7    NaN NaN -234.0    NaN    NaN
# 8    NaN NaN    NaN -234.0    NaN
# 9    NaN NaN    NaN    NaN    NaN

# %%
df.mean()
# Out:
# A    -9.125
# B    30.000
# C     0.750
# D    -2.625
# E    -7.500
# dtype: float64

# %%
df
# Out:
#        A     B      C      D      E
# 0   27.0  45.0   36.0   38.0   28.0
# 1   18.0  26.0   41.0   33.0 -234.0
# 2   10.0  46.0   28.0   22.0   37.0
# 4 -234.0  31.0   45.0   33.0   13.0
# 6   13.0  31.0   10.0   16.0   17.0
# 7   30.0  12.0 -234.0   26.0   44.0
# 8   48.0  34.0   32.0 -234.0   15.0
# 9   15.0  15.0   48.0   45.0   20.0

# %%
df[df==-234] = np.nan

# %%
df
# Out:
#       A     B     C     D     E
# 0  27.0  45.0  36.0  38.0  28.0
# 1  18.0  26.0  41.0  33.0   NaN
# 2  10.0  46.0  28.0  22.0  37.0
# 4   NaN  31.0  45.0  33.0  13.0
# 6  13.0  31.0  10.0  16.0  17.0
# 7  30.0  12.0   NaN  26.0  44.0
# 8  48.0  34.0  32.0   NaN  15.0
# 9  15.0  15.0  48.0  45.0  20.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 0 to 9
# Data columns (total 5 columns):
# A    7 non-null float64
# B    8 non-null float64
# C    7 non-null float64
# D    7 non-null float64
# E    7 non-null float64
# dtypes: float64(5)
# memory usage: 704.0 bytes

# %%
df.describe()
# Out:
#                A          B          C          D          E
# count   7.000000   8.000000   7.000000   7.000000   7.000000
# mean   23.000000  30.000000  34.285714  30.428571  24.857143
# std    13.216152  12.328828  12.815541   9.846440  11.880356
# min    10.000000  12.000000  10.000000  16.000000  13.000000
# 25%    14.000000  23.250000  30.000000  24.000000  16.000000
# 50%    18.000000  31.000000  36.000000  33.000000  20.000000
# 75%    28.500000  36.750000  43.000000  35.500000  32.500000
# max    48.000000  46.000000  48.000000  45.000000  44.000000

# %%
df.median()
# Out:
# A    18.0
# B    31.0
# C    36.0
# D    33.0
# E    20.0
# dtype: float64

# %%
##when there is no outlier in the data then mean is the best measure to replace the null values

# %%
df
# Out:
#       A     B     C     D     E
# 0  27.0  45.0  36.0  38.0  28.0
# 1  18.0  26.0  41.0  33.0   NaN
# 2  10.0  46.0  28.0  22.0  37.0
# 4   NaN  31.0  45.0  33.0  13.0
# 6  13.0  31.0  10.0  16.0  17.0
# 7  30.0  12.0   NaN  26.0  44.0
# 8  48.0  34.0  32.0   NaN  15.0
# 9  15.0  15.0  48.0  45.0  20.0

# %%
df['A'].fillna(df['A'].mean(),inplace=True)

# %%
df
# Out:
#       A     B     C     D     E
# 0  27.0  45.0  36.0  38.0  28.0
# 1  18.0  26.0  41.0  33.0   NaN
# 2  10.0  46.0  28.0  22.0  37.0
# 4  23.0  31.0  45.0  33.0  13.0
# 6  13.0  31.0  10.0  16.0  17.0
# 7  30.0  12.0   NaN  26.0  44.0
# 8  48.0  34.0  32.0   NaN  15.0
# 9  15.0  15.0  48.0  45.0  20.0

# %%
df.mean()
# Out:
# A    23.000000
# B    30.000000
# C    34.285714
# D    30.428571
# E    24.857143
# dtype: float64

# %%
df.fillna(round(df.mean(),1))
# Out:
#       A     B     C     D     E
# 0  27.0  45.0  36.0  38.0  28.0
# 1  18.0  26.0  41.0  33.0  24.9
# 2  10.0  46.0  28.0  22.0  37.0
# 4  23.0  31.0  45.0  33.0  13.0
# 6  13.0  31.0  10.0  16.0  17.0
# 7  30.0  12.0  34.3  26.0  44.0
# 8  48.0  34.0  32.0  30.4  15.0
# 9  15.0  15.0  48.0  45.0  20.0

# %%
def replace_none(df):
    for i in df:
        df[i].fillna(round(df[i].mean(),2),inplace=True)

# %%
replace_none(df)

# %%
df
# Out:
#       A     B          C          D          E
# 0  27.0  45.0  36.000000  38.000000  28.000000
# 1  18.0  26.0  41.000000  33.000000  24.857143
# 2  10.0  46.0  28.000000  22.000000  37.000000
# 4  23.0  31.0  45.000000  33.000000  13.000000
# 6  13.0  31.0  10.000000  16.000000  17.000000
# 7  30.0  12.0  34.285714  26.000000  44.000000
# 8  48.0  34.0  32.000000  30.428571  15.000000
# 9  15.0  15.0  48.000000  45.000000  20.000000

# %%
df.isna()
# Out:
#        A      B      C      D      E
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False  False  False
# 4  False  False  False  False  False
# 6  False  False  False  False  False
# 7  False  False  False  False  False
# 8  False  False  False  False  False
# 9  False  False  False  False  False

# %%
df.describe()
# Out:
#                A          B          C          D          E
# count   8.000000   8.000000   8.000000   8.000000   8.000000
# mean   23.000000  30.000000  34.285714  30.428571  24.857143
# std    12.235779  12.328828  11.864886   9.116032  10.999072
# min    10.000000  12.000000  10.000000  16.000000  13.000000
# 25%    14.500000  23.250000  31.000000  25.000000  16.500000
# 50%    20.500000  31.000000  35.142857  31.714286  22.428571
# 75%    27.750000  36.750000  42.000000  34.250000  30.250000
# max    48.000000  46.000000  48.000000  45.000000  44.000000

# %% [markdown]
# ### Outliers

# %%
arr = np.random.randint(20,50,50)
arr =np.append(arr,np.random.randint(200,300,20))

# %%
arr
# Out:
# array([ 44,  32,  29,  25,  31,  38,  38,  34,  37,  34,  42,  36,  39,
#         48,  41,  31,  46,  20,  28,  36,  45,  40,  26,  39,  33,  36,
#         45,  22,  48,  39,  47,  27,  44,  44,  24,  45,  29,  22,  32,
#         27,  24,  31,  20,  35,  45,  28,  38,  26,  39,  25, 212, 233,
#        210, 265, 233, 221, 285, 267, 228, 246, 281, 287, 217, 213, 260,
#        210, 220, 299, 253, 240])

# %%
np.random.shuffle(arr)

# %%
arr
# Out:
# array([ 20,  24,  38,  37, 246,  44,  26,  39, 260, 212,  32,  32,  38,
#         42,  47,  34, 220,  45,  26,  44,  25,  22,  28,  44, 267,  39,
#         28, 210,  33,  31, 287,  36,  39,  45,  27, 217, 233, 253, 240,
#        213,  45,  45,  40,  41,  27,  29, 299,  39,  31,  25,  34,  22,
#        281,  35, 210, 228,  31, 221,  38,  46,  48, 265,  20,  29,  24,
#        233,  36,  48,  36, 285])

# %%
df = pd.DataFrame(arr.reshape(10,7),columns=list('ABCDEFG'))

# %%
df
# Out:
#      A    B    C    D    E    F    G
# 0   20   24   38   37  246   44   26
# 1   39  260  212   32   32   38   42
# 2   47   34  220   45   26   44   25
# 3   22   28   44  267   39   28  210
# 4   33   31  287   36   39   45   27
# 5  217  233  253  240  213   45   45
# 6   40   41   27   29  299   39   31
# 7   25   34   22  281   35  210  228
# 8   31  221   38   46   48  265   20
# 9   29   24  233   36   48   36  285

# %%
###IOR , Z-Scrore, Visualization

# %%
df['A'].plot(kind='hist',bins=10,ec='k')

# %%
plt.hist(df['A'])
plt.show()

# %%
for i in df:
    plt.hist(df[i],ec='k')
    plt.show()

# %%
df['A'].mean()
# Out:
# 50.3

# %%
df['B'].mean()
# Out:
# 93.0

# %%
#replace the outliers value with the null values 
#replace the null values with the mean

# %%
df['A'][df['A']>75] = np.nan

# %%
df
# Out:
#       A    B    C    D    E    F    G
# 0  20.0   24   38   37  246   44   26
# 1  39.0  260  212   32   32   38   42
# 2  47.0   34  220   45   26   44   25
# 3  22.0   28   44  267   39   28  210
# 4  33.0   31  287   36   39   45   27
# 5   NaN  233  253  240  213   45   45
# 6  40.0   41   27   29  299   39   31
# 7  25.0   34   22  281   35  210  228
# 8  31.0  221   38   46   48  265   20
# 9  29.0   24  233   36   48   36  285

# %%
def remove_out(df,value):
    for i in df:
        df[i][df[i]>value] = np.nan

# %%
remove_out(df,75)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df
# Out:
#       A     B     C     D     E     F     G
# 0  20.0  24.0  38.0  37.0   NaN  44.0  26.0
# 1  39.0   NaN   NaN  32.0  32.0  38.0  42.0
# 2  47.0  34.0   NaN  45.0  26.0  44.0  25.0
# 3  22.0  28.0  44.0   NaN  39.0  28.0   NaN
# 4  33.0  31.0   NaN  36.0  39.0  45.0  27.0
# 5   NaN   NaN   NaN   NaN   NaN  45.0  45.0
# 6  40.0  41.0  27.0  29.0   NaN  39.0  31.0
# 7  25.0  34.0  22.0   NaN  35.0   NaN   NaN
# 8  31.0   NaN  38.0  46.0  48.0   NaN  20.0
# 9  29.0  24.0   NaN  36.0  48.0  36.0   NaN

# %%
replace_none(df)

# %%
df
# Out:
#        A      B     C      D      E      F      G
# 0  20.00  24.00  38.0  37.00  38.14  44.00  26.00
# 1  39.00  30.86  33.8  32.00  32.00  38.00  42.00
# 2  47.00  34.00  33.8  45.00  26.00  44.00  25.00
# 3  22.00  28.00  44.0  37.29  39.00  28.00  30.86
# 4  33.00  31.00  33.8  36.00  39.00  45.00  27.00
# 5  31.78  30.86  33.8  37.29  38.14  45.00  45.00
# 6  40.00  41.00  27.0  29.00  38.14  39.00  31.00
# 7  25.00  34.00  22.0  37.29  35.00  39.88  30.86
# 8  31.00  30.86  38.0  46.00  48.00  39.88  20.00
# 9  29.00  24.00  33.8  36.00  48.00  36.00  30.86

# %%
df.describe()
# Out:
#                A          B          C          D          E          F  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   31.778000  30.858000  33.800000  37.287000  38.142000  39.876000
# std     8.442982   4.998413   6.007403   5.114561   6.590036   5.237419
# min    20.000000  24.000000  22.000000  29.000000  26.000000  28.000000
# 25%    26.000000  28.715000  33.800000  36.000000  35.785000  38.250000
# 50%    31.390000  30.860000  33.800000  37.145000  38.140000  39.880000
# 75%    37.500000  33.250000  36.950000  37.290000  39.000000  44.000000
# max    47.000000  41.000000  44.000000  46.000000  48.000000  45.000000
#
#                G
# count  10.000000
# mean   30.858000
# std     7.563488
# min    20.000000
# 25%    26.250000
# 50%    30.860000
# 75%    30.965000
# max    45.000000

# %%
df['G'].apply(lambda x : x**2)
# Out:
# 0     676.0000
# 1    1764.0000
# 2     625.0000
# 3     952.3396
# 4     729.0000
# 5    2025.0000
# 6     961.0000
# 7     952.3396
# 8     400.0000
# 9     952.3396
# Name: G, dtype: float64

# %%
df['A'] > 34
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# Name: A, dtype: bool

# %%
#functions,dataset
