# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("tmdb_5000_movies.csv")
df2 = pd.read_csv("tmdb_5000_credits.csv")

# %%
df1.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df2.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
#1 
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
# budget                  4803 non-null int64
# genres                  4803 non-null object
# homepage                1712 non-null object
# id                      4803 non-null int64
# keywords                4803 non-null object
# original_language       4803 non-null object
# original_title          4803 non-null object
# overview                4800 non-null object
# popularity              4803 non-null float64
# production_companies    4803 non-null object
# production_countries    4803 non-null object
# release_date            4802 non-null object
# revenue                 4803 non-null int64
# runtime                 4801 non-null float64
# spoken_languages        4803 non-null object
# status                  4803 non-null object
# tagline                 3959 non-null object
# title                   4803 non-null object
# ...

# %%
df1.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
#remove null values
df1[df1.isna()].count()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
df1.dropna(how="any",axis=0).count()
# Out:
# budget                  1493
# genres                  1493
# homepage                1493
# id                      1493
# keywords                1493
# original_language       1493
# original_title          1493
# overview                1493
# popularity              1493
# production_companies    1493
# production_countries    1493
# release_date            1493
# revenue                 1493
# runtime                 1493
# spoken_languages        1493
# status                  1493
# tagline                 1493
# title                   1493
# vote_average            1493
# vote_count              1493
# dtype: int64

# %%
df1.count()
# Out:
# budget                  4803
# genres                  4803
# homepage                1712
# id                      4803
# keywords                4803
# original_language       4803
# original_title          4803
# overview                4800
# popularity              4803
# production_companies    4803
# production_countries    4803
# release_date            4802
# revenue                 4803
# runtime                 4801
# spoken_languages        4803
# status                  4803
# tagline                 3959
# title                   4803
# vote_average            4803
# vote_count              4803
# dtype: int64

# %%
df1.dropna(how="all",axis=0).count()
# Out:
# budget                  4803
# genres                  4803
# homepage                1712
# id                      4803
# keywords                4803
# original_language       4803
# original_title          4803
# overview                4800
# popularity              4803
# production_companies    4803
# production_countries    4803
# release_date            4802
# revenue                 4803
# runtime                 4801
# spoken_languages        4803
# status                  4803
# tagline                 3959
# title                   4803
# vote_average            4803
# vote_count              4803
# dtype: int64

# %%
df1.shape
# Out:
# (4803, 20)

# %%
df1['genres'][0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
#select the columns that you want in your project

# %%
df1.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %% [markdown]
#     [] --> False

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
# budget                  4803 non-null int64
# genres                  4803 non-null object
# homepage                1712 non-null object
# id                      4803 non-null int64
# keywords                4803 non-null object
# original_language       4803 non-null object
# original_title          4803 non-null object
# overview                4800 non-null object
# popularity              4803 non-null float64
# production_companies    4803 non-null object
# production_countries    4803 non-null object
# release_date            4802 non-null object
# revenue                 4803 non-null int64
# runtime                 4801 non-null float64
# spoken_languages        4803 non-null object
# status                  4803 non-null object
# tagline                 3959 non-null object
# title                   4803 non-null object
# ...

# %%
df1.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df1['revenue']
# Out:
# 0       2787965087
# 1        961000000
# 2        880674609
# 3       1084939099
# 4        284139100
#            ...
# 4798       2040920
# 4799             0
# 4800             0
# 4801             0
# 4802             0
# Name: revenue, Length: 4803, dtype: int64

# %%
df1['budget']
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4798       220000
# 4799         9000
# 4800            0
# 4801            0
# 4802            0
# Name: budget, Length: 4803, dtype: int64

# %%
df1['original_language']
# Out:
# 0       en
# 1       en
# 2       en
# 3       en
# 4       en
#         ..
# 4798    es
# 4799    en
# 4800    en
# 4801    en
# 4802    en
# Name: original_language, Length: 4803, dtype: object

# %%
df1['popularity']
# Out:
# 0       150.437577
# 1       139.082615
# 2       107.376788
# 3       112.312950
# 4        43.926995
#            ...
# 4798     14.269792
# 4799      0.642552
# 4800      1.444476
# 4801      0.857008
# 4802      1.929883
# Name: popularity, Length: 4803, dtype: float64

# %%
df1['status']
# Out:
# 0       Released
# 1       Released
# 2       Released
# 3       Released
# 4       Released
#           ...
# 4798    Released
# 4799    Released
# 4800    Released
# 4801    Released
# 4802    Released
# Name: status, Length: 4803, dtype: object

# %%
df1['title']
# Out:
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                    John Carter
#                           ...
# 4798                                 El Mariachi
# 4799                                   Newlyweds
# 4800                   Signed, Sealed, Delivered
# 4801                            Shanghai Calling
# 4802                           My Date with Drew
# Name: title, Length: 4803, dtype: object

# %%
column = ['keywords','overview','production_companies','production_countries','budget','status','title','tagline', 'vote_average','vote_count']
for i in column:
    df1.drop(i,axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['genres', 'homepage', 'id', 'original_language', 'original_title',
#        'popularity', 'release_date', 'revenue', 'runtime', 'spoken_languages'],
#       dtype='object')

# %%
df1.shape
# Out:
# (4803, 10)

# %%
df1.head()
# Out:
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id original_language  \
# 0                   http://www.avatarmovie.com/   19995                en
# 1  http://disney.go.com/disneypictures/pirates/     285                en
# 2   http://www.sonypictures.com/movies/spectre/  206647                en
# 3            http://www.thedarkknightrises.com/   49026                en
# 4          http://movies.disney.com/john-carter   49529                en
#
#                              original_title  popularity release_date  \
# 0                                    Avatar  150.437577   2009-12-10
# ...

# %%
import json
genre = []
for i in df1['genres']:
    g = []
    l1 = json.loads(i)
    for j in l1:
        g.append(j['name'])
    genre.append(g)
    
#print(genre)
df1['genres'] = genre

# %%
df1['genres']
# Out:
# 0       [Action, Adventure, Fantasy, Science Fiction]
# 1                        [Adventure, Fantasy, Action]
# 2                          [Action, Adventure, Crime]
# 3                    [Action, Crime, Drama, Thriller]
# 4                [Action, Adventure, Science Fiction]
#                             ...
# 4798                        [Action, Crime, Thriller]
# 4799                                [Comedy, Romance]
# 4800               [Comedy, Drama, Romance, TV Movie]
# 4801                                               []
# 4802                                    [Documentary]
# Name: genres, Length: 4803, dtype: object

# %%
##### analysis

# %%
df1['original_language'].value_counts()
# Out:
# en    4505
# fr      70
# es      32
# de      27
# zh      27
# hi      19
# ja      16
# it      14
# cn      12
# ko      11
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# he       3
# th       3
# ar       2
# id       2
# cs       2
# ta       2
# ro       2
# nb       1
# pl       1
# is       1
# vi       1
# xx       1
# no       1
# hu       1
# el       1
# ky       1
# te       1
# af       1
# sl       1
# ps       1
# tr       1
# Name: original_language, dtype: int64

# %%
df1[df1['original_language'] == "hi"]
# Out:
#                                   genres  \
# 1023                             [Drama]
# 2962                    [Drama, Romance]
# 2971   [Drama, Comedy, Romance, Foreign]
# 3089           [Action, Science Fiction]
# 3157                    [Drama, Romance]
# 3228                           [Romance]
# 3327           [Family, Comedy, Romance]
# 3374                    [Drama, Romance]
# 3543                             [Drama]
# 3553     [Drama, Action, Crime, Foreign]
# 3645           [Drama, Foreign, History]
# 3722  [Thriller, Action, Drama, History]
# 4166                      [Drama, Music]
# 4198                    [Drama, Romance]
# 4210                           [Romance]
# 4295            [Comedy, Drama, Romance]
# 4331            [Drama, Comedy, Romance]
# 4371           [Drama, Foreign, Romance]
# 4512                [Documentary, Drama]
#
#                                                homepage      id  \
# 1023                                                NaN    7504
# ...

# %%
### ask user that what language spoken movies you need

# %%
### ask genre and show movie according to the genres
### ask title and show its details

# %%
df1['runtime'].value_counts()
# Out:
# 90.0     163
# 100.0    149
# 98.0     140
# 97.0     133
# 95.0     123
#         ...
# 338.0      1
# 53.0       1
# 214.0      1
# 194.0      1
# 179.0      1
# Name: runtime, Length: 156, dtype: int64

# %%
df1[df1['runtime'] > 100].groupby("runtime").count().sort_index()
# Out:
#          genres  homepage   id  original_language  original_title  popularity  \
# runtime
# 101.0       114        45  114                114             114         114
# 102.0       100        51  100                100             100         100
# 103.0        99        28   99                 99              99          99
# 104.0       109        30  109                109             109         109
# 105.0       106        35  106                106             106         106
# ...         ...       ...  ...                ...             ...         ...
# 242.0         1         0    1                  1               1           1
# 248.0         1         0    1                  1               1           1
# 254.0         1         0    1                  1               1           1
# 276.0         1         0    1                  1               1           1
# 338.0         1         0    1                  1               1           1
#
# ...

# %%
df1.groupby('runtime').count()
# Out:
#          genres  homepage  id  original_language  original_title  popularity  \
# runtime
# 14.0          1         0   1                  1               1           1
# 25.0          1         0   1                  1               1           1
# 41.0          1         0   1                  1               1           1
# 42.0          1         0   1                  1               1           1
# 46.0          1         0   1                  1               1           1
# ...         ...       ...  ..                ...             ...         ...
# 242.0         1         0   1                  1               1           1
# 248.0         1         0   1                  1               1           1
# 254.0         1         0   1                  1               1           1
# 276.0         1         0   1                  1               1           1
# 338.0         1         0   1                  1               1           1
#
# ...

# %%
genre = "Action"
df1[df1['genres'].apply(lambda x : True if genre in x else False)][:10]
# Out:
#                                            genres  \
# 0   [Action, Adventure, Fantasy, Science Fiction]
# 1                    [Adventure, Fantasy, Action]
# 2                      [Action, Adventure, Crime]
# 3                [Action, Crime, Drama, Thriller]
# 4            [Action, Adventure, Science Fiction]
# 5                    [Fantasy, Action, Adventure]
# 7            [Action, Adventure, Science Fiction]
# 9                    [Action, Adventure, Fantasy]
# 10  [Adventure, Fantasy, Action, Science Fiction]
# 11           [Adventure, Action, Thriller, Crime]
#
#                                              homepage      id  \
# 0                         http://www.avatarmovie.com/   19995
# 1        http://disney.go.com/disneypictures/pirates/     285
# 2         http://www.sonypictures.com/movies/spectre/  206647
# 3                  http://www.thedarkknightrises.com/   49026
# 4                http://movies.disney.com/john-carter   49529
# ...

# %%
df1
# Out:
#                                              genres  \
# 0     [Action, Adventure, Fantasy, Science Fiction]
# 1                      [Adventure, Fantasy, Action]
# 2                        [Action, Adventure, Crime]
# 3                  [Action, Crime, Drama, Thriller]
# 4              [Action, Adventure, Science Fiction]
# ...                                             ...
# 4798                      [Action, Crime, Thriller]
# 4799                              [Comedy, Romance]
# 4800             [Comedy, Drama, Romance, TV Movie]
# 4801                                             []
# 4802                                  [Documentary]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# ...

# %%
lang = input("\n ENter language hi--> hindi, en--> english : ")
df1[df1['original_language'] == lang].sort_values(by="popularity",ascending=False)[:5][['original_title','homepage']]
# Out:
#  ENter language hi--> hindi, en--> english : hi
#         original_title homepage
# 4198             Dabba      NaN
# 4295   Monsoon Wedding      NaN
# 3157  Jab Tak Hai Jaan      NaN
# 3543   Rang De Basanti      NaN
# 3089               कृष      NaN

# %%
d = df1[df1['original_language'] == lang].sort_values(by="popularity",ascending=False)[:5][['original_title','homepage']]

# %%
d
# Out:
#               original_title                                  homepage
# 546                  Minions              http://www.minionsmovie.com/
# 95              Interstellar         http://www.interstellarmovie.net/
# 788                 Deadpool  http://www.foxmovies.com/movies/deadpool
# 94   Guardians of the Galaxy               http://marvel.com/guardians
# 127       Mad Max: Fury Road               http://www.madmaxmovie.com/

# %%
lang = input("\n ENter language hi--> hindi, en--> english : ")
df1[df1['original_language'] == lang].sort_values(by="release_date",ascending=False)[:5][['original_title','homepage']]
# Out:
#  ENter language hi--> hindi, en--> english : hi
#                original_title                                      homepage
# 3722                  Airlift                                           NaN
# 4512        Faith Connections                                           NaN
# 4198                    Dabba                                           NaN
# 3228  Yeh Jawaani Hai Deewani  http://www.facebook.com/YehJawaaniHaiDeewani
# 4166                  एबीसीडी                                           NaN

# %%
genre = input("\n Enter the genre : ").title()
df1[df1["genres"].apply(lambda x : True if genre in x else False)].sort_values(by="release_date",ascending=False)[:7]['original_title']
# Out:
#  Enter the genre : comedy
# 4255        Growing Up Smith
# 2112                Bad Moms
# 148             Ghostbusters
# 1682           Sausage Party
# 3671             Yoga Hosers
# 914     Central Intelligence
# 370         Now You See Me 2
# Name: original_title, dtype: object

# %%
### short movies and long movies
### language --> release date , popularity??
### genre

# %%
df1.head()
# Out:
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                        homepage      id original_language  \
# 0                   http://www.avatarmovie.com/   19995                en
# 1  http://disney.go.com/disneypictures/pirates/     285                en
# 2   http://www.sonypictures.com/movies/spectre/  206647                en
# 3            http://www.thedarkknightrises.com/   49026                en
# 4          http://movies.disney.com/john-carter   49529                en
#
#                              original_title  popularity release_date  \
# 0                                    Avatar  150.437577   2009-12-10
# 1  Pirates of the Caribbean: At World's End  139.082615   2007-05-19
# ...
