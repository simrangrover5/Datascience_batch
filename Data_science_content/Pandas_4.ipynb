# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def check_expiry(date):
    if date.split("/")[-1] == "25":
        return True
    else:
        return False

# %%
check_expiry("12/2020")
# Out:
# False

# %%
data = pd.read_csv("Ecommerce Purchases.csv")

# %%
data.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
for i in data['CC Exp Date']:
    print(check_expiry(i))
# Out:
# False
# False
# False
# False
# True
# True
# False
# True
# False
# False
# False
# False
# False
# True
# False
# True
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
data[data['CC Exp Date'].apply(check_expiry)]
# Out:
#                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 13    118 Melton Via Suite 681\nAlexanderbury, FL 32104  36 bu       PM
# 15       31730 Chelsea Crest\nBlakemouth, CT 90395-0620  41 Cj       PM
# ...                                                 ...    ...      ...
# 9955      66539 Potts Forge\nCartershire, AK 58271-5180  37 KB       AM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
data[data['CC Exp Date'].apply(lambda x :True if x.split("/")[-1] == "25" else False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 13    118 Melton Via Suite 681\nAlexanderbury, FL 32104  36 bu       PM
# 15       31730 Chelsea Crest\nBlakemouth, CT 90395-0620  41 Cj       PM
# ...                                                 ...    ...      ...
# 9955      66539 Potts Forge\nCartershire, AK 58271-5180  37 KB       AM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Address             10000 non-null object
# Lot                 10000 non-null object
# AM or PM            10000 non-null object
# Browser Info        10000 non-null object
# Company             10000 non-null object
# Credit Card         10000 non-null int64
# CC Exp Date         10000 non-null object
# CC Security Code    10000 non-null int64
# CC Provider         10000 non-null object
# Email               10000 non-null object
# Job                 10000 non-null object
# IP Address          10000 non-null object
# Language            10000 non-null object
# Purchase Price      10000 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
data['Credit Card'].apply(np.cumsum)
# Out:
# 0       [6011929061123406]
# 1       [3337758169645356]
# 2           [675957666125]
# 3       [6011578504430710]
# 4       [6011456623207998]
#                ...
# 9995     [342945015358701]
# 9996     [210033169205009]
# 9997    [6011539787356311]
# 9998     [180003348082930]
# 9999    [4139972901927273]
# Name: Credit Card, Length: 10000, dtype: object

# %%
data.apply(np.cumsum)

# %%
import seaborn as sns

# %%
data = sns.load_dataset("tips")

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
data.apply(np.cumsum)
# Out:
#      total_bill     tip                                                sex  \
# 0         16.99    1.01                                             Female
# 1         27.33    2.67                                         FemaleMale
# 2         48.34    6.17                                     FemaleMaleMale
# 3         72.02    9.48                                 FemaleMaleMaleMale
# 4         96.61   13.09                           FemaleMaleMaleMaleFemale
# ..          ...     ...                                                ...
# 239     4741.32  722.83  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 240     4768.50  724.83  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 241     4791.17  726.83  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 242     4808.99  728.58  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# 243     4827.77  731.58  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
#
#                                                 smoker  \
# ...

# %%
data['tip'].apply(lambda x : x/10)
# Out:
# 0      0.101
# 1      0.166
# 2      0.350
# 3      0.331
# 4      0.361
#        ...
# 239    0.592
# 240    0.200
# 241    0.200
# 242    0.175
# 243    0.300
# Name: tip, Length: 244, dtype: float64

# %%
data[data['total_bill'].apply(lambda x : True if x>14 else False)]['sex']
# Out:
# 0      Female
# 2        Male
# 3        Male
# 4      Female
# 5        Male
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 173, dtype: category
# Categories (2, object): [Male, Female]

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
data['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
data[data['day'].apply(lambda x :True if x.startswith('S') else False)]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [163 rows x 7 columns]

# %%
df = pd.read_csv("matches.csv")

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
# id                 756 non-null int64
# season             756 non-null int64
# city               749 non-null object
# date               756 non-null object
# team1              756 non-null object
# team2              756 non-null object
# toss_winner        756 non-null object
# toss_decision      756 non-null object
# result             756 non-null object
# dl_applied         756 non-null int64
# winner             752 non-null object
# win_by_runs        756 non-null int64
# win_by_wickets     756 non-null int64
# player_of_match    752 non-null object
# venue              756 non-null object
# umpire1            754 non-null object
# umpire2            754 non-null object
# umpire3            119 non-null object
# dtypes: int64(5), object(13)
# memory usage: 106.4+ KB

# %%
df.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
df.tail()
# Out:
#         id  season           city      date                  team1  \
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
df['city'].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan,
#        'Mohali', 'Bengaluru'], dtype=object)

# %%
df['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Ahmedabad          12
# Centurion          12
# Mohali             10
# Rajkot             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Port Elizabeth      7
# Cuttack             7
# Abu Dhabi           7
# Cape Town           7
# Ranchi              7
# Raipur              6
# Sharjah             6
# Kochi               5
# Kanpur              4
# East London         3
# Nagpur              3
# Kimberley           3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
df[df['city'].isna()]['city'].size
# Out:
# 7

# %%
df[df['city'].apply(lambda x :True if str(x).upper().startswith("K") else False)]['city'].value_counts()
# Out:
# Kolkata      77
# Kochi         5
# Kanpur        4
# Kimberley     3
# Name: city, dtype: int64

# %%
df[df['city'].apply(lambda x :True if str(x).upper().startswith("K") else False)]['city'].value_counts().plot(kind='bar')

# %%
df['date'].dtype
# Out:
# dtype('O')

# %%
pd.to_datetime(df['date'])
# Out:
# 0     2017-04-05
# 1     2017-04-06
# 2     2017-04-07
# 3     2017-04-08
# 4     2017-04-08
#          ...
# 751   2019-05-05
# 752   2019-07-05
# 753   2019-08-05
# 754   2019-10-05
# 755   2019-12-05
# Name: date, Length: 756, dtype: datetime64[ns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0     2017-04-05
# 1     2017-04-06
# 2     2017-04-07
# 3     2017-04-08
# 4     2017-04-08
#          ...
# 751   2019-05-05
# 752   2019-07-05
# 753   2019-08-05
# 754   2019-10-05
# 755   2019-12-05
# Name: date, Length: 756, dtype: datetime64[ns]

# %%
years = []
for i in df['date']:
    y = str(i).split("-")[0]
    if y not in years:
        years.append(y)

# %%
years
# Out:
# ['2017',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2018',
#  '2019']

# %%
newdf = df[df['date'].apply(lambda x :True if str(x).split('-')[0] in ["2018" or "2019"] else False)]

# %%
#how many times kkr win the toss and the match
# Out:
#        id  season       city       date                        team1  \
# 636  7894    2018     Mumbai 2018-07-04               Mumbai Indians
# 637  7895    2018     Mohali 2018-08-04             Delhi Daredevils
# 638  7896    2018    Kolkata 2018-08-04  Royal Challengers Bangalore
# 639  7897    2018  Hyderabad 2018-09-04             Rajasthan Royals
# 640  7898    2018    Chennai 2018-10-04        Kolkata Knight Riders
# 641  7899    2018     Jaipur 2018-11-04             Rajasthan Royals
# 642  7900    2018  Hyderabad 2018-12-04               Mumbai Indians
# 643  7901    2018  Bengaluru 2018-04-13              Kings XI Punjab
# 644  7902    2018     Mumbai 2018-04-14               Mumbai Indians
# 645  7903    2018    Kolkata 2018-04-14        Kolkata Knight Riders
# 646  7904    2018  Bengaluru 2018-04-15             Rajasthan Royals
# 647  7905    2018     Mohali 2018-04-15              Kings XI Punjab
# 648  7906    2018    Kolkata 2018-04-16        Kolkata Knight Riders
# ...

# %%
newdf[(newdf['toss_winner'] == "Kolkata Knight Riders") & (newdf['winner'] == "Kolkata Knight Riders")].count()
# Out:
# id                 5
# season             5
# city               5
# date               5
# team1              5
# team2              5
# toss_winner        5
# toss_decision      5
# result             5
# dl_applied         5
# winner             5
# win_by_runs        5
# win_by_wickets     5
# player_of_match    5
# venue              5
# umpire1            5
# umpire2            5
# umpire3            5
# dtype: int64

# %%
newdf['dl_applied'].value_counts()
# Out:
# 0    57
# 1     3
# Name: dl_applied, dtype: int64

# %%
newdf[newdf['dl_applied'] == 1]['winner']
# Out:
# 641    Rajasthan Royals
# 653     Kings XI Punjab
# 667    Delhi Daredevils
# Name: winner, dtype: object

# %%
newdf['player_of_match'].value_counts().apply(lambda x :True if  x >1 else False)
# Out:
# Rashid Khan        True
# SR Watson          True
# SP Narine          True
# AB de Villiers     True
# JC Buttler         True
# SV Samson          True
# CH Gayle           True
# UT Yadav           True
# KL Rahul           True
# AT Rayudu          True
# KS Williamson      True
# CA Lynn            True
# AS Rajpoot         True
# N Rana             True
# RG Sharma          True
# S Dhawan           True
# Ishan Kishan      False
# F du Plessis      False
# RA Jadeja         False
# B Stanlake        False
# HH Pandya         False
# HV Patel          False
# A Mishra          False
# AD Russell        False
# J Archer          False
# RR Pant           False
# DJ Bravo          False
# SW Billings       False
# SS Iyer           False
# TG Southee        False
# JJ Roy            False
# L Ngidi           False
# MS Dhoni          False
# AS Yadav          False
# Kuldeep Yadav     False
# S Gopal           False
# M Ur Rahman       False
# JJ Bumrah         False
# ...

# %%
newdf['player_of_match'].value_counts().plot(kind='bar')

# %%
plt.figure(figsize=(11,6))
newdf['player_of_match'].value_counts(sort=True)[:5].plot(kind='bar')
plt.show()

# %%
#find the player_of_match and the city of the winning place

# %%
newdf[newdf['player_of_match'] == "MS Dhoni"]['city']
# Out:
# 659    Bengaluru
# Name: city, dtype: object

# %%
newdf[newdf['player_of_match'] == "AB de Villiers"]['city'].value_counts()
# Out:
# Bengaluru    2
# Delhi        1
# Name: city, dtype: int64

# %%
df.head()
# Out:
#    id  season       city       date                        team1  \
# 0   1    2017  Hyderabad 2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune 2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot 2017-04-07                Gujarat Lions
# 3   4    2017     Indore 2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore 2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df[['winner','win_by_wickets']]
# Out:
#                           winner  win_by_wickets
# 0            Sunrisers Hyderabad               0
# 1         Rising Pune Supergiant               7
# 2          Kolkata Knight Riders              10
# 3                Kings XI Punjab               6
# 4    Royal Challengers Bangalore               0
# ..                           ...             ...
# 751               Mumbai Indians               9
# 752               Mumbai Indians               6
# 753               Delhi Capitals               2
# 754          Chennai Super Kings               6
# 755               Mumbai Indians               0
#
# [756 rows x 2 columns]

# %%
#calculate how many times team1 won the game and how many times team 2 won the game
#how many time the toss winner won the game as well
#how many times the team win by wickets
